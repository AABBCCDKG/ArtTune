# %%
# !pip install transformers
# !pip install git+https://github.com/openai/CLIP.git
# !pip install tqdm
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-5wbphyig
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-5wbphyig
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.2.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (24.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.66.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.18.0+cu121)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.15.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->clip==1.0)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->clip==1.0)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->clip==1.0)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->clip==1.0)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->clip==1.0)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->clip==1.0)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->clip==1.0)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->clip==1.0)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->clip==1.0)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 50.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->clip==1.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->clip==1.0) (1.3.0)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=aac30214811ce58d62f89034acbbbb2226be72e5c3974e73ec9ac4544ed741a7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y5upsa84/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ftfy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, clip
# Successfully installed clip-1.0 ftfy-6.2.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/drive/MyDrive/image

# %%
import struct
from struct import unpack
import matplotlib.pyplot as plt
from PIL import Image
import os

list_image_path = []
list_txt = []

# Upack the drawing data
def unpack_drawing(file_handle):
    key_id, = unpack('Q', file_handle.read(8)) # Read 8 bytes as an unsigned long long
    country_code, = unpack('2s', file_handle.read(2))
    recognized, = unpack('b', file_handle.read(1))
    timestamp, = unpack('I', file_handle.read(4))
    n_strokes, = unpack('H', file_handle.read(2)) # Read 2 bytes as an unsigned short
    image = [] # Store the strokes
    for i in range(n_strokes):
        n_points, = unpack('H', file_handle.read(2))
        fmt = str(n_points) + 'B'
        x = unpack(fmt, file_handle.read(n_points))
        y = unpack(fmt, file_handle.read(n_points))
        y = tuple(255 - yi for yi in y)  # Invert the image
        image.append((x, y)) # Append the stroke to the image

    return {
        'key_id': key_id,
        'country_code': country_code.decode(),
        'recognized': recognized,
        'timestamp': timestamp,
        'image': image
    }

# Unpack all the drawings in a file
def unpack_drawings(filename):
    with open(filename, 'rb') as f:
      while True:
        try:
          yield unpack_drawing(f)
        except struct.error:
          break

# Plot the drawing
def plot_drawing(drawing):
    if isinstance(drawing, torch.Tensor):
        drawing = drawing.cpu().numpy()

    if drawing.ndim == 2:  # Deal with 2D tensors
        fig, ax = plt.subplots()
        for x, y in drawing:
            ax.plot(x, y)
        plt.show()
    elif drawing.ndim == 4:  # Deal with 4D tensors
        batch_size = drawing.shape[0]
        for i in range(batch_size):
            img = drawing[i].transpose(1, 2, 0)  # Change the shape from (1, 28, 28) to (28, 28, 1)
            img = (img - img.min()) / (img.max() - img.min())  # Normalize the image

            plt.imshow(img)
            plt.title(f"Image {i+1}")
            plt.axis('off')
            plt.show()

def save_drawing_as_image(drawing, folder_path, image_index):
    image = Image.new('L', (256, 256), 255) # Create a white image
    pixels = image.load()

    for x, y in drawing['image']:
        for i in range(len(x)):
          pixels[x[i], y[i]] = 0 # Set the pixel to black
    image_path = os.path.join(folder_path, f'image_{image_index}.png')
    image.save(image_path)

    # choose the first image of each category
    if image_index == 0:
        list_image_path.append(image_path)
        folder_name = os.path.basename(folder_path)
        list_txt.append(folder_name)
    print(f"Saved image {image_index}.jpg to {folder_path}")

def process_bin_files(bin_folder, image_folder, max_images_per_type = 100, num = 1):
    for bin_file in os.listdir(bin_folder):
        if bin_file.endswith('.bin'):
            bin_file_path = os.path.join(bin_folder, bin_file)
            drawing_name = os.path.splitext(bin_file)[0]

            drawing_folder_path = os.path.join(image_folder, drawing_name)
            os.makedirs(drawing_folder_path, exist_ok=True)


            print(f"Processing {bin_file_path}, {num} / 345")
            num += 1

            for image_index, drawing in enumerate(unpack_drawings(bin_file_path)):
                if image_index >= max_images_per_type:
                  break
                save_drawing_as_image(drawing, drawing_folder_path, image_index)

bin_folder = '/content/drive/MyDrive/binary'
image_folder = '/content/drive/MyDrive/image'
os.makedirs(image_folder, exist_ok=True)
process_bin_files(bin_folder, image_folder)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#
/ 345
# Saved image 0.jpg to /content/drive/MyDrive/image/submarine
# Saved image 1.jpg to /content/drive/MyDrive/image/submarine
# Saved image 2.jpg to /content/drive/MyDrive/image/submarine
# Saved image 3.jpg to /content/drive/MyDrive/image/submarine
# Saved image 4.jpg to /content/drive/MyDrive/image/submarine
# Saved image 5.jpg to /content/drive/MyDrive/image/submarine
# Saved image 6.jpg to /content/drive/MyDrive/image/submarine
# Saved image 7.jpg to /content/drive/MyDrive/image/submarine
# Saved image 8.jpg to /content/drive/MyDrive/image/submarine
# Saved image 9.jpg to /content/drive/MyDrive/image/submarine
# Saved image 10.jpg to /content/drive/MyDrive/image/submarine
# Saved image 11.jpg to /content/drive/MyDrive/image/submarine
# Saved image 12.jpg to /content/drive/MyDrive/image/submarine
# Saved image 13.jpg to /content/drive/MyDrive/image/submarine
# Saved image 14.jpg to /content/drive/MyDrive/image/submarine
# Saved image 15.jpg to /content/drive/MyDrive/image/submarine
# Saved image 16.jpg to /content/drive/MyDrive/image/submarine
# Saved image 17.jpg to /content/drive/MyDrive/image/submarine
# Saved image 18.jpg to /content/drive/MyDrive/image/submarine
# Saved image 19.jpg to /content/drive/MyDrive/image/submarine
# Saved image 20.jpg to /content/drive/MyDrive/image/submarine
# Saved image 21.jpg to /content/drive/MyDrive/image/submarine
# Saved image 22.jpg to /content/drive/MyDrive/image/submarine
# Saved image 23.jpg to /content/drive/MyDrive/image/submarine
# Saved image 24.jpg to /content/drive/MyDrive/image/submarine
# Saved image 25.jpg to /content/drive/MyDrive/image/submarine
# Saved image 26.jpg to /content/drive/MyDrive/image/submarine
# Saved image 27.jpg to /content/drive/MyDrive/image/submarine
# Saved image 28.jpg to /content/drive/MyDrive/image/submarine
# Saved image 29.jpg to /content/drive/MyDrive/image/submarine
# Saved image 30.jpg to /content/drive/MyDrive/image/submarine
# Saved image 31.jpg to /content/drive/MyDrive/image/submarine
# Saved image 32.jpg to /content/drive/MyDrive/image/submarine
# Saved image 33.jpg to /content/drive/MyDrive/image/submarine
# Saved image 34.jpg to /content/drive/MyDrive/image/submarine
# Saved image 35.jpg to /content/drive/MyDrive/image/submarine
# Saved image 36.jpg to /content/drive/MyDrive/image/submarine
# Saved image 37.jpg to /content/drive/MyDrive/image/submarine
# Saved image 38.jpg to /content/drive/MyDrive/image/submarine
# Saved image 39.jpg to /content/drive/MyDrive/image/submarine
# Saved image 40.jpg to /content/drive/MyDrive/image/submarine
# Saved image 41.jpg to /content/drive/MyDrive/image/submarine
# Saved image 42.jpg to /content/drive/MyDrive/image/submarine
# Saved image 43.jpg to /content/drive/MyDrive/image/submarine
# Saved image 44.jpg to /content/drive/MyDrive/image/submarine
# Saved image 45.jpg to /content/drive/MyDrive/image/submarine
# Saved image 46.jpg to /content/drive/MyDrive/image/submarine
# Saved image 47.jpg to /content/drive/MyDrive/image/submarine
# Saved image 48.jpg to /content/drive/MyDrive/image/submarine
# Saved image 49.jpg to /content/drive/MyDrive/image/submarine
# Saved image 50.jpg to /content/drive/MyDrive/image/submarine
# Saved image 51.jpg to /content/drive/MyDrive/image/submarine
# Saved image 52.jpg to /content/drive/MyDrive/image/submarine
# Saved image 53.jpg to /content/drive/MyDrive/image/submarine
# Saved image 54.jpg to /content/drive/MyDrive/image/submarine
# Saved image 55.jpg to /content/drive/MyDrive/image/submarine
# Saved image 56.jpg to /content/drive/MyDrive/image/submarine
# Saved image 57.jpg to /content/drive/MyDrive/image/submarine
# Saved image 58.jpg to /content/drive/MyDrive/image/submarine
# Saved image 59.jpg to /content/drive/MyDrive/image/submarine
# Saved image 60.jpg to /content/drive/MyDrive/image/submarine
# Saved image 61.jpg to /content/drive/MyDrive/image/submarine
# Saved image 62.jpg to /content/drive/MyDrive/image/submarine
# Saved image 63.jpg to /content/drive/MyDrive/image/submarine
# Saved image 64.jpg to /content/drive/MyDrive/image/submarine
# Saved image 65.jpg to /content/drive/MyDrive/image/submarine
# Saved image 66.jpg to /content/drive/MyDrive/image/submarine
# Saved image 67.jpg to /content/drive/MyDrive/image/submarine
# Saved image 68.jpg to /content/drive/MyDrive/image/submarine
# Saved image 69.jpg to /content/drive/MyDrive/image/submarine
# Saved image 70.jpg to /content/drive/MyDrive/image/submarine
# Saved image 71.jpg to /content/drive/MyDrive/image/submarine
# Saved image 72.jpg to /content/drive/MyDrive/image/submarine
# Saved image 73.jpg to /content/drive/MyDrive/image/submarine
# Saved image 74.jpg to /content/drive/MyDrive/image/submarine
# Saved image 75.jpg to /content/drive/MyDrive/image/submarine
# Saved image 76.jpg to /content/drive/MyDrive/image/submarine
# Saved image 77.jpg to /content/drive/MyDrive/image/submarine
# Saved image 78.jpg to /content/drive/MyDrive/image/submarine
# Saved image 79.jpg to /content/drive/MyDrive/image/submarine
# Saved image 80.jpg to /content/drive/MyDrive/image/submarine
# Saved image 81.jpg to /content/drive/MyDrive/image/submarine
# Saved image 82.jpg to /content/drive/MyDrive/image/submarine
# Saved image 83.jpg to /content/drive/MyDrive/image/submarine
# Saved image 84.jpg to /content/drive/MyDrive/image/submarine
# Saved image 85.jpg to /content/drive/MyDrive/image/submarine
# Saved image 86.jpg to /content/drive/MyDrive/image/submarine
# Saved image 87.jpg to /content/drive/MyDrive/image/submarine
# Saved image 88.jpg to /content/drive/MyDrive/image/submarine
# Saved image 89.jpg to /content/drive/MyDrive/image/submarine
# Saved image 90.jpg to /content/drive/MyDrive/image/submarine
# Saved image 91.jpg to /content/drive/MyDrive/image/submarine
# Saved image 92.jpg to /content/drive/MyDrive/image/submarine
# Saved image 93.jpg to /content/drive/MyDrive/image/submarine
# Saved image 94.jpg to /content/drive/MyDrive/image/submarine
# Saved image 95.jpg to /content/drive/MyDrive/image/submarine
# Saved image 96.jpg to /content/drive/MyDrive/image/submarine
# Saved image 97.jpg to /content/drive/MyDrive/image/submarine
# Saved image 98.jpg to /content/drive/MyDrive/image/submarine
# Saved image 99.jpg to /content/drive/MyDrive/image/submarine
# Processing /content/drive/MyDrive/binary/underwear.bin, 300 / 345
# Saved image 0.jpg to /content/drive/MyDrive/image/underwear
# Saved image 1.jpg to /content/drive/MyDrive/image/underwear
# Saved image 2.jpg to /content/drive/MyDrive/image/underwear
# Saved image 3.jpg to /content/drive/MyDrive/image/underwear
# Saved image 4.jpg to /content/drive/MyDrive/image/underwear
# Saved image 5.jpg to /content/drive/MyDrive/image/underwear
# Saved image 6.jpg to /content/drive/MyDrive/image/underwear
# Saved image 7.jpg to /content/drive/MyDrive/image/underwear
# Saved image 8.jpg to /content/drive/MyDrive/image/underwear
# Saved image 9.jpg to /content/drive/MyDrive/image/underwear
# Saved image 10.jpg to /content/drive/MyDrive/image/underwear
# Saved image 11.jpg to /content/drive/MyDrive/image/underwear
# Saved image 12.jpg to /content/drive/MyDrive/image/underwear
# Saved image 13.jpg to /content/drive/MyDrive/image/underwear
# Saved image 14.jpg to /content/drive/MyDrive/image/underwear
# Saved image 15.jpg to /content/drive/MyDrive/image/underwear
# Saved image 16.jpg to /content/drive/MyDrive/image/underwear
# Saved image 17.jpg to /content/drive/MyDrive/image/underwear
# Saved image 18.jpg to /content/drive/MyDrive/image/underwear
# Saved image 19.jpg to /content/drive/MyDrive/image/underwear
# Saved image 20.jpg to /content/drive/MyDrive/image/underwear
# Saved image 21.jpg to /content/drive/MyDrive/image/underwear
# Saved image 22.jpg to /content/drive/MyDrive/image/underwear
# Saved image 23.jpg to /content/drive/MyDrive/image/underwear
# Saved image 24.jpg to /content/drive/MyDrive/image/underwear
# Saved image 25.jpg to /content/drive/MyDrive/image/underwear
# Saved image 26.jpg to /content/drive/MyDrive/image/underwear
# Saved image 27.jpg to /content/drive/MyDrive/image/underwear
# Saved image 28.jpg to /content/drive/MyDrive/image/underwear
# Saved image 29.jpg to /content/drive/MyDrive/image/underwear
# Saved image 30.jpg to /content/drive/MyDrive/image/underwear
# Saved image 31.jpg to /content/drive/MyDrive/image/underwear
# Saved image 32.jpg to /content/drive/MyDrive/image/underwear
# Saved image 33.jpg to /content/drive/MyDrive/image/underwear
# Saved image 34.jpg to /content/drive/MyDrive/image/underwear
# Saved image 35.jpg to /content/drive/MyDrive/image/underwear
# Saved image 36.jpg to /content/drive/MyDrive/image/underwear
# Saved image 37.jpg to /content/drive/MyDrive/image/underwear
# Saved image 38.jpg to /content/drive/MyDrive/image/underwear
# Saved image 39.jpg to /content/drive/MyDrive/image/underwear
# Saved image 40.jpg to /content/drive/MyDrive/image/underwear
# Saved image 41.jpg to /content/drive/MyDrive/image/underwear
# Saved image 42.jpg to /content/drive/MyDrive/image/underwear
# Saved image 43.jpg to /content/drive/MyDrive/image/underwear
# Saved image 44.jpg to /content/drive/MyDrive/image/underwear
# Saved image 45.jpg to /content/drive/MyDrive/image/underwear
# Saved image 46.jpg to /content/drive/MyDrive/image/underwear
# Saved image 47.jpg to /content/drive/MyDrive/image/underwear
# Saved image 48.jpg to /content/drive/MyDrive/image/underwear
# Saved image 49.jpg to /content/drive/MyDrive/image/underwear
# Saved image 50.jpg to /content/drive/MyDrive/image/underwear
# Saved image 51.jpg to /content/drive/MyDrive/image/underwear
# Saved image 52.jpg to /content/drive/MyDrive/image/underwear
# Saved image 53.jpg to /content/drive/MyDrive/image/underwear
# Saved image 54.jpg to /content/drive/MyDrive/image/underwear
# Saved image 55.jpg to /content/drive/MyDrive/image/underwear
# Saved image 56.jpg to /content/drive/MyDrive/image/underwear
# Saved image 57.jpg to /content/drive/MyDrive/image/underwear
# Saved image 58.jpg to /content/drive/MyDrive/image/underwear
# Saved image 59.jpg to /content/drive/MyDrive/image/underwear
# Saved image 60.jpg to /content/drive/MyDrive/image/underwear
# Saved image 61.jpg to /content/drive/MyDrive/image/underwear
# Saved image 62.jpg to /content/drive/MyDrive/image/underwear
# Saved image 63.jpg to /content/drive/MyDrive/image/underwear
# Saved image 64.jpg to /content/drive/MyDrive/image/underwear
# Saved image 65.jpg to /content/drive/MyDrive/image/underwear
# Saved image 66.jpg to /content/drive/MyDrive/image/underwear
# Saved image 67.jpg to /content/drive/MyDrive/image/underwear
# Saved image 68.jpg to /content/drive/MyDrive/image/underwear
# Saved image 69.jpg to /content/drive/MyDrive/image/underwear
# Saved image 70.jpg to /content/drive/MyDrive/image/underwear
# Saved image 71.jpg to /content/drive/MyDrive/image/underwear
# Saved image 72.jpg to /content/drive/MyDrive/image/underwear
# Saved image 73.jpg to /content/drive/MyDrive/image/underwear
# Saved image 74.jpg to /content/drive/MyDrive/image/underwear
# Saved image 75.jpg to /content/drive/MyDrive/image/underwear
# Saved image 76.jpg to /content/drive/MyDrive/image/underwear
# Saved image 77.jpg to /content/drive/MyDrive/image/underwear
# Saved image 78.jpg to /content/drive/MyDrive/image/underwear
# Saved image 79.jpg to /content/drive/MyDrive/image/underwear
# Saved image 80.jpg to /content/drive/MyDrive/image/underwear
# Saved image 81.jpg to /content/drive/MyDrive/image/underwear
# Saved image 82.jpg to /content/drive/MyDrive/image/underwear
# Saved image 83.jpg to /content/drive/MyDrive/image/underwear
# Saved image 84.jpg to /content/drive/MyDrive/image/underwear
# Saved image 85.jpg to /content/drive/MyDrive/image/underwear
# Saved image 86.jpg to /content/drive/MyDrive/image/underwear
# Saved image 87.jpg to /content/drive/MyDrive/image/underwear
# Saved image 88.jpg to /content/drive/MyDrive/image/underwear
# Saved image 89.jpg to /content/drive/MyDrive/image/underwear
# Saved image 90.jpg to /content/drive/MyDrive/image/underwear
# Saved image 91.jpg to /content/drive/MyDrive/image/underwear
# Saved image 92.jpg to /content/drive/MyDrive/image/underwear
# Saved image 93.jpg to /content/drive/MyDrive/image/underwear
# Saved image 94.jpg to /content/drive/MyDrive/image/underwear
# Saved image 95.jpg to /content/drive/MyDrive/image/underwear
# Saved image 96.jpg to /content/drive/MyDrive/image/underwear
# Saved image 97.jpg to /content/drive/MyDrive/image/underwear
# Saved image 98.jpg to /content/drive/MyDrive/image/underwear
# Saved image 99.jpg to /content/drive/MyDrive/image/underwear
# Processing /content/drive/MyDrive/binary/vase.bin, 301 / 345
# Saved image 0.jpg to /content/drive/MyDrive/image/vase
# Saved image 1.jpg to /content/drive/MyDrive/image/vase
# Saved image 2.jpg to /content/drive/MyDrive/image/vase
# Saved image 3.jpg to /content/drive/MyDrive/image/vase
# Saved image 4.jpg to /content/drive/MyDrive/image/vase
# Saved image 5.jpg to /content/drive/MyDrive/image/vase
# Saved image 6.jpg to /content/drive/MyDrive/image/vase
# Saved image 7.jpg to /content/drive/MyDrive/image/vase
# Saved image 8.jpg to /content/drive/MyDrive/image/vase
# Saved image 9.jpg to /content/drive/MyDrive/image/vase
# Saved image 10.jpg to /content/drive/MyDrive/image/vase
# Saved image 11.jpg to /content/drive/MyDrive/image/vase
# Saved image 12.jpg to /content/drive/MyDrive/image/vase
# Saved image 13.jpg to /content/drive/MyDrive/image/vase
# Saved image 14.jpg to /content/drive/MyDrive/image/vase
# Saved image 15.jpg to /content/drive/MyDrive/image/vase
# Saved image 16.jpg to /content/drive/MyDrive/image/vase
# Saved image 17.jpg to /content/drive/MyDrive/image/vase
# Saved image 18.jpg to /content/drive/MyDrive/image/vase
# Saved image 19.jpg to /content/drive/MyDrive/image/vase
# Saved image 20.jpg to /content/drive/MyDrive/image/vase
# Saved image 21.jpg to /content/drive/MyDrive/image/vase
# Saved image 22.jpg to /content/drive/MyDrive/image/vase
# Saved image 23.jpg to /content/drive/MyDrive/image/vase
# Saved image 24.jpg to /content/drive/MyDrive/image/vase
# Saved image 25.jpg to /content/drive/MyDrive/image/vase
# Saved image 26.jpg to /content/drive/MyDrive/image/vase
# Saved image 27.jpg to /content/drive/MyDrive/image/vase
# Saved image 28.jpg to /content/drive/MyDrive/image/vase
# Saved image 29.jpg to /content/drive/MyDrive/image/vase
# Saved image 30.jpg to /content/drive/MyDrive/image/vase
# Saved image 31.jpg to /content/drive/MyDrive/image/vase
# Saved image 32.jpg to /content/drive/MyDrive/image/vase
# Saved image 33.jpg to /content/drive/MyDrive/image/vase
# Saved image 34.jpg to /content/drive/MyDrive/image/vase
# Saved image 35.jpg to /content/drive/MyDrive/image/vase
# Saved image 36.jpg to /content/drive/MyDrive/image/vase
# Saved image 37.jpg to /content/drive/MyDrive/image/vase
# Saved image 38.jpg to /content/drive/MyDrive/image/vase
# Saved image 39.jpg to /content/drive/MyDrive/image/vase
# Saved image 40.jpg to /content/drive/MyDrive/image/vase
# Saved image 41.jpg to /content/drive/MyDrive/image/vase
# Saved image 42.jpg to /content/drive/MyDrive/image/vase
# Saved image 43.jpg to /content/drive/MyDrive/image/vase
# Saved image 44.jpg to /content/drive/MyDrive/image/vase
# Saved image 45.jpg to /content/drive/MyDrive/image/vase
# Saved image 46.jpg to /content/drive/MyDrive/image/vase
# Saved image 47.jpg to /content/drive/MyDrive/image/vase
# Saved image 48.jpg to /content/drive/MyDrive/image/vase
# Saved image 49.jpg to /content/drive/MyDrive/image/vase
# Saved image 50.jpg to /content/drive/MyDrive/image/vase
# Saved image 51.jpg to /content/drive/MyDrive/image/vase
# Saved image 52.jpg to /content/drive/MyDrive/image/vase
# Saved image 53.jpg to /content/drive/MyDrive/image/vase
# Saved image 54.jpg to /content/drive/MyDrive/image/vase
# Saved image 55.jpg to /content/drive/MyDrive/image/vase
# Saved image 56.jpg to /content/drive/MyDrive/image/vase
# Saved image 57.jpg to /content/drive/MyDrive/image/vase
# Saved image 58.jpg to /content/drive/MyDrive/image/vase
# Saved image 59.jpg to /content/drive/MyDrive/image/vase
# Saved image 60.jpg to /content/drive/MyDrive/image/vase
# Saved image 61.jpg to /content/drive/MyDrive/image/vase
# Saved image 62.jpg to /content/drive/MyDrive/image/vase
# Saved image 63.jpg to /content/drive/MyDrive/image/vase
# Saved image 64.jpg to /content/drive/MyDrive/image/vase
# Saved image 65.jpg to /content/drive/MyDrive/image/vase
# Saved image 66.jpg to /content/drive/MyDrive/image/vase
# Saved image 67.jpg to /content/drive/MyDrive/image/vase
# Saved image 68.jpg to /content/drive/MyDrive/image/vase
# Saved image 69.jpg to /content/drive/MyDrive/image/vase
# Saved image 70.jpg to /content/drive/MyDrive/image/vase
# Saved image 71.jpg to /content/drive/MyDrive/image/vase
# Saved image 72.jpg to /content/drive/MyDrive/image/vase
# Saved image 73.jpg to /content/drive/MyDrive/image/vase
# Saved image 74.jpg to /content/drive/MyDrive/image/vase
# Saved image 75.jpg to /content/drive/MyDrive/image/vase
# Saved image 76.jpg to /content/drive/MyDrive/image/vase
# Saved image 77.jpg to /content/drive/MyDrive/image/vase
# Saved image 78.jpg to /content/drive/MyDrive/image/vase
# Saved image 79.jpg to /content/drive/MyDrive/image/vase
# Saved image 80.jpg to /content/drive/MyDrive/image/vase
# Saved image 81.jpg to /content/drive/MyDrive/image/vase
# Saved image 82.jpg to /content/drive/MyDrive/image/vase
# Saved image 83.jpg to /content/drive/MyDrive/image/vase
# Saved image 84.jpg to /content/drive/MyDrive/image/vase
# Saved image 85.jpg to /content/drive/MyDrive/image/vase
# Saved image 86.jpg to /content/drive/MyDrive/image/vase
# Saved image 87.jpg to /content/drive/MyDrive/image/vase
# Saved image 88.jpg to /content/drive/MyDrive/image/vase
# Saved image 89.jpg to /content/drive/MyDrive/image/vase
# Saved image 90.jpg to /content/drive/MyDrive/image/vase
# Saved image 91.jpg to /content/drive/MyDrive/image/vase
# Saved image 92.jpg to /content/drive/MyDrive/image/vase
# Saved image 93.jpg to /content/drive/MyDrive/image/vase
# Saved image 94.jpg to /content/drive/MyDrive/image/vase
# Saved image 95.jpg to /content/drive/MyDrive/image/vase
# Saved image 96.jpg to /content/drive/MyDrive/image/vase
# Saved image 97.jpg to /content/drive/MyDrive/image/vase
# Saved image 98.jpg to /content/drive/MyDrive/image/vase
# Saved image 99.jpg to /content/drive/MyDrive/image/vase
# Processing /content/drive/MyDrive/binary/sock.bin, 302 / 345
# Saved image 0.jpg to /content/drive/MyDrive/image/sock
# Saved image 1.jpg to /content/drive/MyDrive/image/sock
# Saved image 2.jpg to /content/drive/MyDrive/image/sock
# Saved image 3.jpg to /content/drive/MyDrive/image/sock
# Saved image 4.jpg to /content/drive/MyDrive/image/sock
# Saved image 5.jpg to /content/drive/MyDrive/image/sock
# Saved image 6.jpg to /content/drive/MyDrive/image/sock
# Saved image 7.jpg to /content/drive/MyDrive/image/sock
# Saved image 8.jpg to /content/drive/MyDrive/image/sock
# Saved image 9.jpg to /content/drive/MyDrive/image/sock
# Saved image 10.jpg to /content/drive/MyDrive/image/sock
# Saved image 11.jpg to /content/drive/MyDrive/image/sock
# Saved image 12.jpg to /content/drive/MyDrive/image/sock
# Saved image 13.jpg to /content/drive/MyDrive/image/sock
# Saved image 14.jpg to /content/drive/MyDrive/image/sock
# Saved image 15.jpg to /content/drive/MyDrive/image/sock
# Saved image 16.jpg to /content/drive/MyDrive/image/sock
# Saved image 17.jpg to /content/drive/MyDrive/image/sock
# Saved image 18.jpg to /content/drive/MyDrive/image/sock
# Saved image 19.jpg to /content/drive/MyDrive/image/sock
# Saved image 20.jpg to /content/drive/MyDrive/image/sock
# Saved image 21.jpg to /content/drive/MyDrive/image/sock
# Saved image 22.jpg to /content/drive/MyDrive/image/sock
# Saved image 23.jpg to /content/drive/MyDrive/image/sock
# Saved image 24.jpg to /content/drive/MyDrive/image/sock
# Saved image 25.jpg to /content/drive/MyDrive/image/sock
# Saved image 26.jpg to /content/drive/MyDrive/image/sock
# Saved image 27.jpg to /content/drive/MyDrive/image/sock
# Saved image 28.jpg to /content/drive/MyDrive/image/sock
# Saved image 29.jpg to /content/drive/MyDrive/image/sock
# Saved image 30.jpg to /content/drive/MyDrive/image/sock
# Saved image 31.jpg to /content/drive/MyDrive/image/sock
# Saved image 32.jpg to /content/drive/MyDrive/image/sock
# Saved image 33.jpg to /content/drive/MyDrive/image/sock
# Saved image 34.jpg to /content/drive/MyDrive/image/sock
# Saved image 35.jpg to /content/drive/MyDrive/image/sock
# Saved image 36.jpg to /content/drive/MyDrive/image/sock
# Saved image 37.jpg to /content/drive/MyDrive/image/sock
# Saved image 38.jpg to /content/drive/MyDrive/image/sock
# Saved image 39.jpg to /content/drive/MyDrive/image/sock
# Saved image 40.jpg to /content/drive/MyDrive/image/sock
# Saved image 41.jpg to /content/drive/MyDrive/image/sock
# Saved image 42.jpg to /content/drive/MyDrive/image/sock
# Saved image 43.jpg to /content/drive/MyDrive/image/sock
# Saved image 44.jpg to /content/drive/MyDrive/image/sock
# Saved image 45.jpg to /content/drive/MyDrive/image/sock
# Saved image 46.jpg to /content/drive/MyDrive/image/sock
# Saved image 47.jpg to /content/drive/MyDrive/image/sock
# Saved image 48.jpg to /content/drive/MyDrive/image/sock
# Saved image 49.jpg to /content/drive/MyDrive/image/sock
# Saved image 50.jpg to /content/drive/MyDrive/image/sock
# Saved image 51.jpg to /content/drive/MyDrive/image/sock
# Saved image 52.jpg to /content/drive/MyDrive/image/sock
# Saved image 53.jpg to /content/drive/MyDrive/image/sock
# Saved image 54.jpg to /content/drive/MyDrive/image/sock
# Saved image 55.jpg to /content/drive/MyDrive/image/sock
# Saved image 56.jpg to /content/drive/MyDrive/image/sock
# Saved image 57.jpg to /content/drive/MyDrive/image/sock
# Saved image 58.jpg to /content/drive/MyDrive/image/sock
# Saved image 59.jpg to /content/drive/MyDrive/image/sock
# Saved image 60.jpg to /content/drive/MyDrive/image/sock
# Saved image 61.jpg to /content/drive/MyDrive/image/sock
# Saved image 62.jpg to /content/drive/MyDrive/image/sock
# Saved image 63.jpg to /content/drive/MyDrive/image/sock
# Saved image 64.jpg to /content/drive/MyDrive/image/sock
# Saved image 65.jpg to /content/drive/MyDrive/image/sock
# Saved image 66.jpg to /content/drive/MyDrive/image/sock
# Saved image 67.jpg to /content/drive/MyDrive/image/sock
# Saved image 68.jpg to /content/drive/MyDrive/image/sock
# Saved image 69.jpg to /content/drive/MyDrive/image/sock
# Saved image 70.jpg to /content/drive/MyDrive/image/sock
# Saved image 71.jpg to /content/drive/MyDrive/image/sock
# Saved image 72.jpg to /content/drive/MyDrive/image/sock
# Saved image 73.jpg to /content/drive/MyDrive/image/sock
# Saved image 74.jpg to /content/drive/MyDrive/image/sock
# Saved image 75.jpg to /content/drive/MyDrive/image/sock
# Saved image 76.jpg to /content/drive/MyDrive/image/sock
# Saved image 77.jpg to /content/drive/MyDrive/image/sock
# Saved image 78.jpg to /content/drive/MyDrive/image/sock
# Saved image 79.jpg to /content/drive/MyDrive/image/sock
# Saved image 80.jpg to /content/drive/MyDrive/image/sock
# Saved image 81.jpg to /content/drive/MyDrive/image/sock
# Saved image 82.jpg to /content/drive/MyDrive/image/sock
# Saved image 83.jpg to /content/drive/MyDrive/image/sock
# Saved image 84.jpg to /content/drive/MyDrive/image/sock
# Saved image 85.jpg to /content/drive/MyDrive/image/sock
# Saved image 86.jpg to /content/drive/MyDrive/image/sock
# Saved image 87.jpg to /content/drive/MyDrive/image/sock
# Saved image 88.jpg to /content/drive/MyDrive/image/sock
# Saved image 89.jpg to /content/drive/MyDrive/image/sock
# Saved image 90.jpg to /content/drive/MyDrive/image/sock
# Saved image 91.jpg to /content/drive/MyDrive/image/sock
# Saved image 92.jpg to /content/drive/MyDrive/image/sock
# Saved image 93.jpg to /content/drive/MyDrive/image/sock
# Saved image 94.jpg to /content/drive/MyDrive/image/sock
# Saved image 95.jpg to /content/drive/MyDrive/image/sock
# Saved image 96.jpg to /content/drive/MyDrive/image/sock
# Saved image 97.jpg to /content/drive/MyDrive/image/sock
# Saved image 98.jpg to /content/drive/MyDrive/image/sock
# Saved image 99.jpg to /content/drive/MyDrive/image/sock
# Processing /content/drive/MyDrive/binary/wine bottle.bin, 303 / 345
# Saved image 0.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 1.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 2.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 3.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 4.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 5.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 6.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 7.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 8.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 9.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 10.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 11.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 12.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 13.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 14.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 15.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 16.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 17.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 18.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 19.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 20.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 21.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 22.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 23.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 24.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 25.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 26.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 27.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 28.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 29.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 30.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 31.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 32.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 33.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 34.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 35.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 36.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 37.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 38.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 39.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 40.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 41.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 42.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 43.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 44.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 45.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 46.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 47.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 48.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 49.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 50.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 51.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 52.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 53.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 54.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 55.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 56.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 57.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 58.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 59.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 60.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 61.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 62.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 63.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 64.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 65.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 66.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 67.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 68.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 69.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 70.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 71.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 72.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 73.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 74.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 75.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 76.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 77.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 78.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 79.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 80.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 81.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 82.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 83.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 84.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 85.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 86.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 87.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 88.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 89.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 90.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 91.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 92.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 93.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 94.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 95.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 96.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 97.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 98.jpg to /content/drive/MyDrive/image/wine bottle
# Saved image 99.jpg to /content/drive/MyDrive/image/wine bottle
# Processing /content/drive/MyDrive/binary/whale.bin, 304 / 345
# Saved image 0.jpg to /content/drive/MyDrive/image/whale
# Saved image 1.jpg to /content/drive/MyDrive/image/whale
# Saved image 2.jpg to /content/drive/MyDrive/image/whale
# Saved image 3.jpg to /content/drive/MyDrive/image/whale
# Saved image 4.jpg to /content/drive/MyDrive/image/whale
# Saved image 5.jpg to /content/drive/MyDrive/image/whale
# Saved image 6.jpg to /content/drive/MyDrive/image/whale
# Saved image 7.jpg to /content/drive/MyDrive/image/whale
# Saved image 8.jpg to /content/drive/MyDrive/image/whale
# Saved image 9.jpg to /content/drive/MyDrive/image/whale
# Saved image 10.jpg to /content/drive/MyDrive/image/whale
# Saved image 11.jpg to /content/drive/MyDrive/image/whale
# Saved image 12.jpg to /content/drive/MyDrive/image/whale
# Saved image 13.jpg to /content/drive/MyDrive/image/whale
# Saved image 14.jpg to /content/drive/MyDrive/image/whale
# Saved image 15.jpg to /content/drive/MyDrive/image/whale
# Saved image 16.jpg to /content/drive/MyDrive/image/whale
# Saved image 17.jpg to /content/drive/MyDrive/image/whale
# Saved image 18.jpg to /content/drive/MyDrive/image/whale
# Saved image 19.jpg to /content/drive/MyDrive/image/whale
# Saved image 20.jpg to /content/drive/MyDrive/image/whale
# Saved image 21.jpg to /content/drive/MyDrive/image/whale
# Saved image 22.jpg to /content/drive/MyDrive/image/whale
# Saved image 23.jpg to /content/drive/MyDrive/image/whale
# Saved image 24.jpg to /content/drive/MyDrive/image/whale
# Saved image 25.jpg to /content/drive/MyDrive/image/whale
# Saved image 26.jpg to /content/drive/MyDrive/image/whale
# Saved image 27.jpg to /content/drive/MyDrive/image/whale
# Saved image 28.jpg to /content/drive/MyDrive/image/whale
# Saved image 29.jpg to /content/drive/MyDrive/image/whale
# Saved image 30.jpg to /content/drive/MyDrive/image/whale
# Saved image 31.jpg to /content/drive/MyDrive/image/whale
# Saved image 32.jpg to /content/drive/MyDrive/image/whale
# Saved image 33.jpg to /content/drive/MyDrive/image/whale
# Saved image 34.jpg to /content/drive/MyDrive/image/whale
# Saved image 35.jpg to /content/drive/MyDrive/image/whale
# Saved image 36.jpg to /content/drive/MyDrive/image/whale
# Saved image 37.jpg to /content/drive/MyDrive/image/whale
# ...
# Saved image 25.jpg to /content/drive/MyDrive/image/zebra
# Saved image 26.jpg to /content/drive/MyDrive/image/zebra
# Saved image 27.jpg to /content/drive/MyDrive/image/zebra
# Saved image 28.jpg to /content/drive/MyDrive/image/zebra
# Saved image 29.jpg to /content/drive/MyDrive/image/zebra
# Saved image 30.jpg to /content/drive/MyDrive/image/zebra
# Saved image 31.jpg to /content/drive/MyDrive/image/zebra
# Saved image 32.jpg to /content/drive/MyDrive/image/zebra
# Saved image 33.jpg to /content/drive/MyDrive/image/zebra
# Saved image 34.jpg to /content/drive/MyDrive/image/zebra
# Saved image 35.jpg to /content/drive/MyDrive/image/zebra
# Saved image 36.jpg to /content/drive/MyDrive/image/zebra
# Saved image 37.jpg to /content/drive/MyDrive/image/zebra
# Saved image 38.jpg to /content/drive/MyDrive/image/zebra
# Saved image 39.jpg to /content/drive/MyDrive/image/zebra
# Saved image 40.jpg to /content/drive/MyDrive/image/zebra
# Saved image 41.jpg to /content/drive/MyDrive/image/zebra
# Saved image 42.jpg to /content/drive/MyDrive/image/zebra
# Saved image 43.jpg to /content/drive/MyDrive/image/zebra
# Saved image 44.jpg to /content/drive/MyDrive/image/zebra
# Saved image 45.jpg to /content/drive/MyDrive/image/zebra
# Saved image 46.jpg to /content/drive/MyDrive/image/zebra
# Saved image 47.jpg to /content/drive/MyDrive/image/zebra
# Saved image 48.jpg to /content/drive/MyDrive/image/zebra
# Saved image 49.jpg to /content/drive/MyDrive/image/zebra
# Saved image 50.jpg to /content/drive/MyDrive/image/zebra
# Saved image 51.jpg to /content/drive/MyDrive/image/zebra
# Saved image 52.jpg to /content/drive/MyDrive/image/zebra
# Saved image 53.jpg to /content/drive/MyDrive/image/zebra
# Saved image 54.jpg to /content/drive/MyDrive/image/zebra
# Saved image 55.jpg to /content/drive/MyDrive/image/zebra
# Saved image 56.jpg to /content/drive/MyDrive/image/zebra
# Saved image 57.jpg to /content/drive/MyDrive/image/zebra
# Saved image 58.jpg to /content/drive/MyDrive/image/zebra
# Saved image 59.jpg to /content/drive/MyDrive/image/zebra
# Saved image 60.jpg to /content/drive/MyDrive/image/zebra
# Saved image 61.jpg to /content/drive/MyDrive/image/zebra
# Saved image 62.jpg to /content/drive/MyDrive/image/zebra
# Saved image 63.jpg to /content/drive/MyDrive/image/zebra
# Saved image 64.jpg to /content/drive/MyDrive/image/zebra
# Saved image 65.jpg to /content/drive/MyDrive/image/zebra
# Saved image 66.jpg to /content/drive/MyDrive/image/zebra
# Saved image 67.jpg to /content/drive/MyDrive/image/zebra
# Saved image 68.jpg to /content/drive/MyDrive/image/zebra
# Saved image 69.jpg to /content/drive/MyDrive/image/zebra
# Saved image 70.jpg to /content/drive/MyDrive/image/zebra
# Saved image 71.jpg to /content/drive/MyDrive/image/zebra
# Saved image 72.jpg to /content/drive/MyDrive/image/zebra
# Saved image 73.jpg to /content/drive/MyDrive/image/zebra
# Saved image 74.jpg to /content/drive/MyDrive/image/zebra
# Saved image 75.jpg to /content/drive/MyDrive/image/zebra
# Saved image 76.jpg to /content/drive/MyDrive/image/zebra
# Saved image 77.jpg to /content/drive/MyDrive/image/zebra
# Saved image 78.jpg to /content/drive/MyDrive/image/zebra
# Saved image 79.jpg to /content/drive/MyDrive/image/zebra
# Saved image 80.jpg to /content/drive/MyDrive/image/zebra
# Saved image 81.jpg to /content/drive/MyDrive/image/zebra
# Saved image 82.jpg to /content/drive/MyDrive/image/zebra
# Saved image 83.jpg to /content/drive/MyDrive/image/zebra
# Saved image 84.jpg to /content/drive/MyDrive/image/zebra
# Saved image 85.jpg to /content/drive/MyDrive/image/zebra
# Saved image 86.jpg to /content/drive/MyDrive/image/zebra
# Saved image 87.jpg to /content/drive/MyDrive/image/zebra
# Saved image 88.jpg to /content/drive/MyDrive/image/zebra
# Saved image 89.jpg to /content/drive/MyDrive/image/zebra
# Saved image 90.jpg to /content/drive/MyDrive/image/zebra
# Saved image 91.jpg to /content/drive/MyDrive/image/zebra
# Saved image 92.jpg to /content/drive/MyDrive/image/zebra
# Saved image 93.jpg to /content/drive/MyDrive/image/zebra
# Saved image 94.jpg to /content/drive/MyDrive/image/zebra
# Saved image 95.jpg to /content/drive/MyDrive/image/zebra
# Saved image 96.jpg to /content/drive/MyDrive/image/zebra
# Saved image 97.jpg to /content/drive/MyDrive/image/zebra
# Saved image 98.jpg to /content/drive/MyDrive/image/zebra
# Saved image 99.jpg to /content/drive/MyDrive/image/zebra
# Processing /content/drive/MyDrive/binary/tornado.bin, 344 / 345
# Saved image 0.jpg to /content/drive/MyDrive/image/tornado
# Saved image 1.jpg to /content/drive/MyDrive/image/tornado
# Saved image 2.jpg to /content/drive/MyDrive/image/tornado
# Saved image 3.jpg to /content/drive/MyDrive/image/tornado
# Saved image 4.jpg to /content/drive/MyDrive/image/tornado
# Saved image 5.jpg to /content/drive/MyDrive/image/tornado
# Saved image 6.jpg to /content/drive/MyDrive/image/tornado
# Saved image 7.jpg to /content/drive/MyDrive/image/tornado
# Saved image 8.jpg to /content/drive/MyDrive/image/tornado
# Saved image 9.jpg to /content/drive/MyDrive/image/tornado
# Saved image 10.jpg to /content/drive/MyDrive/image/tornado
# Saved image 11.jpg to /content/drive/MyDrive/image/tornado
# Saved image 12.jpg to /content/drive/MyDrive/image/tornado
# Saved image 13.jpg to /content/drive/MyDrive/image/tornado
# Saved image 14.jpg to /content/drive/MyDrive/image/tornado
# Saved image 15.jpg to /content/drive/MyDrive/image/tornado
# Saved image 16.jpg to /content/drive/MyDrive/image/tornado
# Saved image 17.jpg to /content/drive/MyDrive/image/tornado
# Saved image 18.jpg to /content/drive/MyDrive/image/tornado
# Saved image 19.jpg to /content/drive/MyDrive/image/tornado
# Saved image 20.jpg to /content/drive/MyDrive/image/tornado
# Saved image 21.jpg to /content/drive/MyDrive/image/tornado
# Saved image 22.jpg to /content/drive/MyDrive/image/tornado
# Saved image 23.jpg to /content/drive/MyDrive/image/tornado
# Saved image 24.jpg to /content/drive/MyDrive/image/tornado
# Saved image 25.jpg to /content/drive/MyDrive/image/tornado
# Saved image 26.jpg to /content/drive/MyDrive/image/tornado
# Saved image 27.jpg to /content/drive/MyDrive/image/tornado
# Saved image 28.jpg to /content/drive/MyDrive/image/tornado
# Saved image 29.jpg to /content/drive/MyDrive/image/tornado
# Saved image 30.jpg to /content/drive/MyDrive/image/tornado
# Saved image 31.jpg to /content/drive/MyDrive/image/tornado
# Saved image 32.jpg to /content/drive/MyDrive/image/tornado
# Saved image 33.jpg to /content/drive/MyDrive/image/tornado
# Saved image 34.jpg to /content/drive/MyDrive/image/tornado
# Saved image 35.jpg to /content/drive/MyDrive/image/tornado
# Saved image 36.jpg to /content/drive/MyDrive/image/tornado
# Saved image 37.jpg to /content/drive/MyDrive/image/tornado
# Saved image 38.jpg to /content/drive/MyDrive/image/tornado
# Saved image 39.jpg to /content/drive/MyDrive/image/tornado
# Saved image 40.jpg to /content/drive/MyDrive/image/tornado
# Saved image 41.jpg to /content/drive/MyDrive/image/tornado
# Saved image 42.jpg to /content/drive/MyDrive/image/tornado
# Saved image 43.jpg to /content/drive/MyDrive/image/tornado
# Saved image 44.jpg to /content/drive/MyDrive/image/tornado
# Saved image 45.jpg to /content/drive/MyDrive/image/tornado
# Saved image 46.jpg to /content/drive/MyDrive/image/tornado
# Saved image 47.jpg to /content/drive/MyDrive/image/tornado
# Saved image 48.jpg to /content/drive/MyDrive/image/tornado
# Saved image 49.jpg to /content/drive/MyDrive/image/tornado
# Saved image 50.jpg to /content/drive/MyDrive/image/tornado
# Saved image 51.jpg to /content/drive/MyDrive/image/tornado
# Saved image 52.jpg to /content/drive/MyDrive/image/tornado
# Saved image 53.jpg to /content/drive/MyDrive/image/tornado
# Saved image 54.jpg to /content/drive/MyDrive/image/tornado
# Saved image 55.jpg to /content/drive/MyDrive/image/tornado
# Saved image 56.jpg to /content/drive/MyDrive/image/tornado
# Saved image 57.jpg to /content/drive/MyDrive/image/tornado
# Saved image 58.jpg to /content/drive/MyDrive/image/tornado
# Saved image 59.jpg to /content/drive/MyDrive/image/tornado
# Saved image 60.jpg to /content/drive/MyDrive/image/tornado
# Saved image 61.jpg to /content/drive/MyDrive/image/tornado
# Saved image 62.jpg to /content/drive/MyDrive/image/tornado
# Saved image 63.jpg to /content/drive/MyDrive/image/tornado
# Saved image 64.jpg to /content/drive/MyDrive/image/tornado
# Saved image 65.jpg to /content/drive/MyDrive/image/tornado
# Saved image 66.jpg to /content/drive/MyDrive/image/tornado
# Saved image 67.jpg to /content/drive/MyDrive/image/tornado
# Saved image 68.jpg to /content/drive/MyDrive/image/tornado
# Saved image 69.jpg to /content/drive/MyDrive/image/tornado
# Saved image 70.jpg to /content/drive/MyDrive/image/tornado
# Saved image 71.jpg to /content/drive/MyDrive/image/tornado
# Saved image 72.jpg to /content/drive/MyDrive/image/tornado
# Saved image 73.jpg to /content/drive/MyDrive/image/tornado
# Saved image 74.jpg to /content/drive/MyDrive/image/tornado
# Saved image 75.jpg to /content/drive/MyDrive/image/tornado
# Saved image 76.jpg to /content/drive/MyDrive/image/tornado
# Saved image 77.jpg to /content/drive/MyDrive/image/tornado
# Saved image 78.jpg to /content/drive/MyDrive/image/tornado
# Saved image 79.jpg to /content/drive/MyDrive/image/tornado
# Saved image 80.jpg to /content/drive/MyDrive/image/tornado
# Saved image 81.jpg to /content/drive/MyDrive/image/tornado
# Saved image 82.jpg to /content/drive/MyDrive/image/tornado
# Saved image 83.jpg to /content/drive/MyDrive/image/tornado
# Saved image 84.jpg to /content/drive/MyDrive/image/tornado
# Saved image 85.jpg to /content/drive/MyDrive/image/tornado
# Saved image 86.jpg to /content/drive/MyDrive/image/tornado
# Saved image 87.jpg to /content/drive/MyDrive/image/tornado
# Saved image 88.jpg to /content/drive/MyDrive/image/tornado
# Saved image 89.jpg to /content/drive/MyDrive/image/tornado
# Saved image 90.jpg to /content/drive/MyDrive/image/tornado
# Saved image 91.jpg to /content/drive/MyDrive/image/tornado
# Saved image 92.jpg to /content/drive/MyDrive/image/tornado
# Saved image 93.jpg to /content/drive/MyDrive/image/tornado
# Saved image 94.jpg to /content/drive/MyDrive/image/tornado
# Saved image 95.jpg to /content/drive/MyDrive/image/tornado
# Saved image 96.jpg to /content/drive/MyDrive/image/tornado
# Saved image 97.jpg to /content/drive/MyDrive/image/tornado
# Saved image 98.jpg to /content/drive/MyDrive/image/tornado
# Saved image 99.jpg to /content/drive/MyDrive/image/tornado
# Processing /content/drive/MyDrive/binary/yoga.bin, 345 / 345
# Saved image 0.jpg to /content/drive/MyDrive/image/yoga
# Saved image 1.jpg to /content/drive/MyDrive/image/yoga
# Saved image 2.jpg to /content/drive/MyDrive/image/yoga
# Saved image 3.jpg to /content/drive/MyDrive/image/yoga
# Saved image 4.jpg to /content/drive/MyDrive/image/yoga
# Saved image 5.jpg to /content/drive/MyDrive/image/yoga
# Saved image 6.jpg to /content/drive/MyDrive/image/yoga
# Saved image 7.jpg to /content/drive/MyDrive/image/yoga
# Saved image 8.jpg to /content/drive/MyDrive/image/yoga
# Saved image 9.jpg to /content/drive/MyDrive/image/yoga
# Saved image 10.jpg to /content/drive/MyDrive/image/yoga
# Saved image 11.jpg to /content/drive/MyDrive/image/yoga
# Saved image 12.jpg to /content/drive/MyDrive/image/yoga
# Saved image 13.jpg to /content/drive/MyDrive/image/yoga
# Saved image 14.jpg to /content/drive/MyDrive/image/yoga
# Saved image 15.jpg to /content/drive/MyDrive/image/yoga
# Saved image 16.jpg to /content/drive/MyDrive/image/yoga
# Saved image 17.jpg to /content/drive/MyDrive/image/yoga
# Saved image 18.jpg to /content/drive/MyDrive/image/yoga
# Saved image 19.jpg to /content/drive/MyDrive/image/yoga
# Saved image 20.jpg to /content/drive/MyDrive/image/yoga
# Saved image 21.jpg to /content/drive/MyDrive/image/yoga
# Saved image 22.jpg to /content/drive/MyDrive/image/yoga
# Saved image 23.jpg to /content/drive/MyDrive/image/yoga
# Saved image 24.jpg to /content/drive/MyDrive/image/yoga
# Saved image 25.jpg to /content/drive/MyDrive/image/yoga
# Saved image 26.jpg to /content/drive/MyDrive/image/yoga
# Saved image 27.jpg to /content/drive/MyDrive/image/yoga
# Saved image 28.jpg to /content/drive/MyDrive/image/yoga
# Saved image 29.jpg to /content/drive/MyDrive/image/yoga
# Saved image 30.jpg to /content/drive/MyDrive/image/yoga
# Saved image 31.jpg to /content/drive/MyDrive/image/yoga
# Saved image 32.jpg to /content/drive/MyDrive/image/yoga
# Saved image 33.jpg to /content/drive/MyDrive/image/yoga
# Saved image 34.jpg to /content/drive/MyDrive/image/yoga
# Saved image 35.jpg to /content/drive/MyDrive/image/yoga
# Saved image 36.jpg to /content/drive/MyDrive/image/yoga
# Saved image 37.jpg to /content/drive/MyDrive/image/yoga
# Saved image 38.jpg to /content/drive/MyDrive/image/yoga
# Saved image 39.jpg to /content/drive/MyDrive/image/yoga
# Saved image 40.jpg to /content/drive/MyDrive/image/yoga
# Saved image 41.jpg to /content/drive/MyDrive/image/yoga
# Saved image 42.jpg to /content/drive/MyDrive/image/yoga
# Saved image 43.jpg to /content/drive/MyDrive/image/yoga
# Saved image 44.jpg to /content/drive/MyDrive/image/yoga
# Saved image 45.jpg to /content/drive/MyDrive/image/yoga
# Saved image 46.jpg to /content/drive/MyDrive/image/yoga
# Saved image 47.jpg to /content/drive/MyDrive/image/yoga
# Saved image 48.jpg to /content/drive/MyDrive/image/yoga
# Saved image 49.jpg to /content/drive/MyDrive/image/yoga
# Saved image 50.jpg to /content/drive/MyDrive/image/yoga
# Saved image 51.jpg to /content/drive/MyDrive/image/yoga
# Saved image 52.jpg to /content/drive/MyDrive/image/yoga
# Saved image 53.jpg to /content/drive/MyDrive/image/yoga
# Saved image 54.jpg to /content/drive/MyDrive/image/yoga
# Saved image 55.jpg to /content/drive/MyDrive/image/yoga
# Saved image 56.jpg to /content/drive/MyDrive/image/yoga
# Saved image 57.jpg to /content/drive/MyDrive/image/yoga
# Saved image 58.jpg to /content/drive/MyDrive/image/yoga
# Saved image 59.jpg to /content/drive/MyDrive/image/yoga
# Saved image 60.jpg to /content/drive/MyDrive/image/yoga
# Saved image 61.jpg to /content/drive/MyDrive/image/yoga
# Saved image 62.jpg to /content/drive/MyDrive/image/yoga
# Saved image 63.jpg to /content/drive/MyDrive/image/yoga
# Saved image 64.jpg to /content/drive/MyDrive/image/yoga
# Saved image 65.jpg to /content/drive/MyDrive/image/yoga
# Saved image 66.jpg to /content/drive/MyDrive/image/yoga
# Saved image 67.jpg to /content/drive/MyDrive/image/yoga
# Saved image 68.jpg to /content/drive/MyDrive/image/yoga
# Saved image 69.jpg to /content/drive/MyDrive/image/yoga
# Saved image 70.jpg to /content/drive/MyDrive/image/yoga
# Saved image 71.jpg to /content/drive/MyDrive/image/yoga
# Saved image 72.jpg to /content/drive/MyDrive/image/yoga
# Saved image 73.jpg to /content/drive/MyDrive/image/yoga
# Saved image 74.jpg to /content/drive/MyDrive/image/yoga
# Saved image 75.jpg to /content/drive/MyDrive/image/yoga
# Saved image 76.jpg to /content/drive/MyDrive/image/yoga
# Saved image 77.jpg to /content/drive/MyDrive/image/yoga
# Saved image 78.jpg to /content/drive/MyDrive/image/yoga
# Saved image 79.jpg to /content/drive/MyDrive/image/yoga
# Saved image 80.jpg to /content/drive/MyDrive/image/yoga
# Saved image 81.jpg to /content/drive/MyDrive/image/yoga
# Saved image 82.jpg to /content/drive/MyDrive/image/yoga
# Saved image 83.jpg to /content/drive/MyDrive/image/yoga
# Saved image 84.jpg to /content/drive/MyDrive/image/yoga
# Saved image 85.jpg to /content/drive/MyDrive/image/yoga
# Saved image 86.jpg to /content/drive/MyDrive/image/yoga
# Saved image 87.jpg to /content/drive/MyDrive/image/yoga
# Saved image 88.jpg to /content/drive/MyDrive/image/yoga
# Saved image 89.jpg to /content/drive/MyDrive/image/yoga
# Saved image 90.jpg to /content/drive/MyDrive/image/yoga
# Saved image 91.jpg to /content/drive/MyDrive/image/yoga
# Saved image 92.jpg to /content/drive/MyDrive/image/yoga
# Saved image 93.jpg to /content/drive/MyDrive/image/yoga
# Saved image 94.jpg to /content/drive/MyDrive/image/yoga
# Saved image 95.jpg to /content/drive/MyDrive/image/yoga
# Saved image 96.jpg to /content/drive/MyDrive/image/yoga
# Saved image 97.jpg to /content/drive/MyDrive/image/yoga
# Saved image 98.jpg to /content/drive/MyDrive/image/yoga
# Saved image 99.jpg to /content/drive/MyDrive/image/yoga
# "\nfor drawing in unpack_drawings('/content/drive/MyDrive/binary/rain.bin'):\n    plot_drawing(drawing)\n"

# %%
print(list_image_path)
print(list_txt)
print(len(list_image_path))
print(len(list_txt))
# Out:
# ['/content/drive/MyDrive/image/boomerang/image_0.png', '/content/drive/MyDrive/image/aircraft carrier/image_0.png', '/content/drive/MyDrive/image/bottlecap/image_0.png', '/content/drive/MyDrive/image/The Eiffel Tower/image_0.png', '/content/drive/MyDrive/image/bowtie/image_0.png', '/content/drive/MyDrive/image/bracelet/image_0.png', '/content/drive/MyDrive/image/bread/image_0.png', '/content/drive/MyDrive/image/brain/image_0.png', '/content/drive/MyDrive/image/airplane/image_0.png', '/content/drive/MyDrive/image/broccoli/image_0.png', '/content/drive/MyDrive/image/bucket/image_0.png', '/content/drive/MyDrive/image/bridge/image_0.png', '/content/drive/MyDrive/image/bus/image_0.png', '/content/drive/MyDrive/image/bench/image_0.png', '/content/drive/MyDrive/image/arm/image_0.png', '/content/drive/MyDrive/image/butterfly/image_0.png', '/content/drive/MyDrive/image/baseball bat/image_0.png', '/content/drive/MyDrive/image/axe/image_0.png', '/content/drive/MyDrive/image/anvil/image_0.png', '/content/drive/MyDrive/image/cactus/image_0.png', '/content/drive/MyDrive/image/bed/image_0.png', '/content/drive/MyDrive/image/camel/image_0.png', '/content/drive/MyDrive/image/calendar/image_0.png', '/content/drive/MyDrive/image/candle/image_0.png', '/content/drive/MyDrive/image/blueberry/image_0.png', '/content/drive/MyDrive/image/broom/image_0.png', '/content/drive/MyDrive/image/book/image_0.png', '/content/drive/MyDrive/image/apple/image_0.png', '/content/drive/MyDrive/image/camouflage/image_0.png', '/content/drive/MyDrive/image/beach/image_0.png', '/content/drive/MyDrive/image/bush/image_0.png', '/content/drive/MyDrive/image/bicycle/image_0.png', '/content/drive/MyDrive/image/barn/image_0.png', '/content/drive/MyDrive/image/baseball/image_0.png', '/content/drive/MyDrive/image/ceiling fan/image_0.png', '/content/drive/MyDrive/image/camera/image_0.png', '/content/drive/MyDrive/image/bat/image_0.png', '/content/drive/MyDrive/image/basket/image_0.png', '/content/drive/MyDrive/image/binoculars/image_0.png', '/content/drive/MyDrive/image/backpack/image_0.png', '/content/drive/MyDrive/image/belt/image_0.png', '/content/drive/MyDrive/image/animal migration/image_0.png', '/content/drive/MyDrive/image/bandage/image_0.png', '/content/drive/MyDrive/image/canoe/image_0.png', '/content/drive/MyDrive/image/birthday cake/image_0.png', '/content/drive/MyDrive/image/bathtub/image_0.png', '/content/drive/MyDrive/image/basketball/image_0.png', '/content/drive/MyDrive/image/alarm clock/image_0.png', '/content/drive/MyDrive/image/car/image_0.png', '/content/drive/MyDrive/image/ant/image_0.png', '/content/drive/MyDrive/image/bird/image_0.png', '/content/drive/MyDrive/image/cooler/image_0.png', '/content/drive/MyDrive/image/The Mona Lisa/image_0.png', '/content/drive/MyDrive/image/circle/image_0.png', '/content/drive/MyDrive/image/asparagus/image_0.png', '/content/drive/MyDrive/image/cake/image_0.png', '/content/drive/MyDrive/image/bee/image_0.png', '/content/drive/MyDrive/image/cup/image_0.png', '/content/drive/MyDrive/image/crocodile/image_0.png', '/content/drive/MyDrive/image/The Great Wall of China/image_0.png', '/content/drive/MyDrive/image/bear/image_0.png', '/content/drive/MyDrive/image/diamond/image_0.png', '/content/drive/MyDrive/image/door/image_0.png', '/content/drive/MyDrive/image/calculator/image_0.png', '/content/drive/MyDrive/image/drill/image_0.png', '/content/drive/MyDrive/image/dumbbell/image_0.png', '/content/drive/MyDrive/image/bulldozer/image_0.png', '/content/drive/MyDrive/image/ambulance/image_0.png', '/content/drive/MyDrive/image/duck/image_0.png', '/content/drive/MyDrive/image/church/image_0.png', '/content/drive/MyDrive/image/envelope/image_0.png', '/content/drive/MyDrive/image/crown/image_0.png', '/content/drive/MyDrive/image/cell phone/image_0.png', '/content/drive/MyDrive/image/castle/image_0.png', '/content/drive/MyDrive/image/eraser/image_0.png', '/content/drive/MyDrive/image/banana/image_0.png', '/content/drive/MyDrive/image/angel/im ...
# ['boomerang', 'aircraft carrier', 'bottlecap', 'The Eiffel Tower', 'bowtie', 'bracelet', 'bread', 'brain', 'airplane', 'broccoli', 'bucket', 'bridge', 'bus', 'bench', 'arm', 'butterfly', 'baseball bat', 'axe', 'anvil', 'cactus', 'bed', 'camel', 'calendar', 'candle', 'blueberry', 'broom', 'book', 'apple', 'camouflage', 'beach', 'bush', 'bicycle', 'barn', 'baseball', 'ceiling fan', 'camera', 'bat', 'basket', 'binoculars', 'backpack', 'belt', 'animal migration', 'bandage', 'canoe', 'birthday cake', 'bathtub', 'basketball', 'alarm clock', 'car', 'ant', 'bird', 'cooler', 'The Mona Lisa', 'circle', 'asparagus', 'cake', 'bee', 'cup', 'crocodile', 'The Great Wall of China', 'bear', 'diamond', 'door', 'calculator', 'drill', 'dumbbell', 'bulldozer', 'ambulance', 'duck', 'church', 'envelope', 'crown', 'cell phone', 'castle', 'eraser', 'banana', 'angel', 'dresser', 'feather', 'fire hydrant', 'eye', 'crayon', 'clarinet', 'carrot', 'fan', 'dolphin', 'ear', 'clock', 'cello', 'fork', 'dog', 'cannon', 'cloud', 'flamingo', 'computer', 'elbow', 'cruise ship', 'fish', 'campfire', 'couch', 'diving board', 'chair', 'chandelier', 'finger', 'compass', 'dishwasher', 'grass', 'beard', 'garden hose', 'fence', 'crab', 'face', 'dragon', 'elephant', 'cat', 'cow', 'hat', 'donut', 'blackberry', 'frying pan', 'cookie', 'coffee cup', 'ice cream', 'hot tub', 'hourglass', 'harp', 'jail', 'hexagon', 'hockey stick', 'flip flops', 'headphones', 'drums', 'keyboard', 'hammer', 'helmet', 'golf club', 'flower', 'floor lamp', 'leaf', 'hamburger', 'house', 'lightning', 'foot', 'giraffe', 'lantern', 'frog', 'hurricane', 'horse', 'knife', 'ladder', 'light bulb', 'hot air balloon', 'flying saucer', 'guitar', 'laptop', 'eyeglasses', 'jacket', 'hockey puck', 'line', 'lighter', 'leg', 'mouse', 'fireplace', 'house plant', 'hedgehog', 'helicopter', 'flashlight', 'mountain', 'hand', 'hospital', 'mouth', 'hot dog', 'lighthouse', 'key', 'garden', 'mug', 'microwave', 'lipstick', 'passport', 'nose', 'knee', 'palm tree', 'mosquito', 'lollipop', 'mailbox', 'octagon', 'ocean', 'kangaroo', 'pear', 'paper clip', 'penguin', 'moon', 'megaphone', 'moustache', 'nail', 'matches', 'popsicle', 'firetruck', 'goatee', 'mushroom', 'panda', 'pencil', 'map', 'police car', 'microphone', 'pillow', 'necklace', 'piano', 'grapes', 'pond', 'peanut', 'onion', 'pants', 'paint can', 'purse', 'raccoon', 'parachute', 'owl', 'remote control', 'saw', 'postcard', 'octopus', 'rifle', 'paintbrush', 'pineapple', 'monkey', 'pool', 'peas', 'rainbow', 'rain', 'motorbike', 'picture frame', 'lion', 'river', 'pickup truck', 'scissors', 'pizza', 'lobster', 'sailboat', 'sandwich', 'shorts', 'oven', 'parrot', 'pliers', 'marker', 'rake', 'rabbit', 'radio', 'spoon', 'power outlet', 'see saw', 'square', 'potato', 'shoe', 'screwdriver', 'saxophone', 'mermaid', 'star', 'sheep', 'stereo', 'stop sign', 'stairs', 'strawberry', 'swan', 'roller coaster', 'suitcase', 'rhinoceros', 'shark', 'steak', 'sword', 'rollerskates', 'shovel', 'snowflake', 'television', 'skateboard', 't-shirt', 'sun', 'snake', 'swing set', 'syringe', 'stitches', 'teapot', 'spreadsheet', 'table', 'sea turtle', 'streetlight', 'smiley face', 'school bus', 'squiggle', 'toaster', 'snorkel', 'sleeping bag', 'skyscraper', 'string bean', 'sweater', 'umbrella', 'soccer ball', 'stethoscope', 'submarine', 'underwear', 'vase', 'sock', 'wine bottle', 'whale', 'windmill', 'snail', 'violin', 'tent', 'waterslide', 'zigzag', 'triangle', 'wine glass', 'telephone', 'pig', 'skull', 'speedboat', 'teddy-bear', 'scorpion', 'tooth', 'stove', 'toe', 'wristwatch', 'toothpaste', 'squirrel', 'toilet', 'spider', 'toothbrush', 'tiger', 'wheel', 'trumpet', 'washing machine', 'traffic light', 'truck', 'tractor', 'train', 'sink', 'watermelon', 'van', 'tennis racquet', 'snowman', 'trombone', 'tree', 'zebra', 'tornado', 'yoga']
# 345
# 345

# %%
import json # Import the json module: handling JSON data
from PIL import Image # Import the image module from the PIL library: image processing

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.optim as optim

import clip
from transformers import CLIPProcessor, CLIPModel
from tqdm import tqdm

# Load the model and corresponding preprocessor for image and text
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
preprocess = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

class image_title_dataset():
    def __init__(self, list_image_path,list_txt):
        # Initialize image paths and corresponding texts
        self.image_path = list_image_path
        # Tokenize text using CLIP's tokenizer
        self.title  = clip.tokenize(list_txt)

    def __len__(self):
        return len(self.title)

    def __getitem__(self, idx):
        # Preprocess image using CLIP's preprocessing function
        image = preprocess(images=Image.open(self.image_path[idx]), return_tensors="pt")["pixel_values"].squeeze(0)
        title = self.title[idx]
        return image, title


dataset = image_title_dataset(list_image_path[:100],list_txt[:100])
BATCH_SIZE = 2 # should greater than 1
train_dataloader = DataLoader(dataset,batch_size = BATCH_SIZE) #Define your own dataloader

#https://github.com/openai/CLIP/issues/57
def convert_models_to_fp32(model):
    for p in model.parameters():
        p.data = p.data.float()
        p.grad.data = p.grad.data.float()

if device == "cpu":
  model.float()

loss_img = nn.CrossEntropyLoss()
loss_txt = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr = 1e-6, betas = (0.9, 0.98), eps = 1e-6, weight_decay = 0.2)

num_epochs = 300
for epoch in range(num_epochs):
    pbar = tqdm(train_dataloader, total = len(train_dataloader))
    for batch in pbar:
        optimizer.zero_grad()

        images, texts = batch
        images = images.to(device)
        texts = texts.to(device)

        # Forward pass
        outputs = model(pixel_values=images, input_ids=texts)
        logits_per_image, logits_per_text = outputs.logits_per_image, outputs.logits_per_text


         # Check for nan values in logits
        if torch.isnan(logits_per_image).any() or torch.isnan(logits_per_text).any():
            print("Found nan values in logits")
            continue

        # Calculate loss
        ground_truth = torch.arange(len(images), dtype = torch.long, device = device)
        total_loss = (loss_img(logits_per_image, ground_truth) + loss_txt(logits_per_text, ground_truth))/2

        # Backward pass
        total_loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0) # ensure no grad explord

        if device == "cuda":
            optimizer.step()
        else:
            convert_models_to_fp32(model)
            optimizer.step()
            clip.model.convert_weights(model)
        pbar.set_description(f"EPOCH: {epoch}/{num_epochs}, LOSS: {total_loss.item():.9f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# EPOCH: 0/300, LOSS: 0.613207221: 100%|██████████| 50/50 [00:09<00:00,  5.17it/s]
# EPOCH: 1/300, LOSS: 0.631505609: 100%|██████████| 50/50 [00:07<00:00,  6.44it/s]
# EPOCH: 2/300, LOSS: 0.667812526: 100%|██████████| 50/50 [00:07<00:00,  6.99it/s]
# EPOCH: 3/300, LOSS: 0.631917715: 100%|██████████| 50/50 [00:07<00:00,  6.82it/s]
# EPOCH: 4/300, LOSS: 0.576780915: 100%|██████████| 50/50 [00:08<00:00,  5.76it/s]
# EPOCH: 5/300, LOSS: 0.482101589: 100%|██████████| 50/50 [00:06<00:00,  7.28it/s]
# EPOCH: 6/300, LOSS: 0.388072282: 100%|██████████| 50/50 [00:07<00:00,  6.44it/s]
# EPOCH: 7/300, LOSS: 0.313265145: 100%|██████████| 50/50 [00:07<00:00,  7.10it/s]
# EPOCH: 8/300, LOSS: 0.274166286: 100%|██████████| 50/50 [00:07<00:00,  6.51it/s]
# EPOCH: 9/300, LOSS: 0.252338111: 100%|██████████| 50/50 [00:07<00:00,  7.07it/s]
# EPOCH: 10/300, LOSS: 0.227543026: 100%|██████████| 50/50 [00:07<00:00,  6.28it/s]
# EPOCH: 11/300, LOSS: 0.210558996: 100%|██████████| 50/50 [00:07<00:00,  7.14it/s]
# EPOCH: 12/300, LOSS: 0.192993164: 100%|██████████| 50/50 [00:07<00:00,  6.39it/s]
# EPOCH: 290/300, LOSS: 0.693150282: 100%|██████████| 50/50 [00:08<00:00,  6.13it/s]
# EPOCH: 291/300, LOSS: 0.693150043: 100%|██████████| 50/50 [00:07<00:00,  6.87it/s]
# EPOCH: 292/300, LOSS: 0.693149984: 100%|██████████| 50/50 [00:07<00:00,  6.54it/s]
# EPOCH: 293/300, LOSS: 0.693149805: 100%|██████████| 50/50 [00:08<00:00,  5.95it/s]
# EPOCH: 294/300, LOSS: 0.693149745: 100%|██████████| 50/50 [00:07<00:00,  6.93it/s]
# EPOCH: 295/300, LOSS: 0.693149686: 100%|██████████| 50/50 [00:08<00:00,  6.19it/s]
# EPOCH: 296/300, LOSS: 0.693149567: 100%|██████████| 50/50 [00:07<00:00,  6.52it/s]
# EPOCH: 297/300, LOSS: 0.693149328: 100%|██████████| 50/50 [00:07<00:00,  6.33it/s]
# EPOCH: 298/300, LOSS: 0.693149209: 100%|██████████| 50/50 [00:08<00:00,  5.78it/s]
# EPOCH: 299/300, LOSS: 0.693149030: 100%|██████████| 50/50 [00:07<00:00,  6.55it/s]

# %%
# Save the model
checkpoint_dir = "model_checkpoint"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
torch.save({
    'epoch': epoch,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'loss': total_loss,
    }, f"model_checkpoint/model_10.pt")

# %%
# Load the model
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
modeltuning = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
preprocess = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

checkpoint = torch.load("model_checkpoint/model_10.pt")
modeltuning.load_state_dict(checkpoint['model_state_dict'])

model.eval()
modeltuning.eval()

device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)
modeltuning.to(device)
# Out:
# CLIPModel(
#   (text_model): CLIPTextTransformer(
#     (embeddings): CLIPTextEmbeddings(
#       (token_embedding): Embedding(49408, 512)
#       (position_embedding): Embedding(77, 512)
#     )
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (layer_norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#           (layer_norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (vision_model): CLIPVisionTransformer(
#     (embeddings): CLIPVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#       (position_embedding): Embedding(50, 768)
#     )
#     (pre_layrnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (visual_projection): Linear(in_features=768, out_features=512, bias=False)
#   (text_projection): Linear(in_features=512, out_features=512, bias=False)
# )

# %%
# preprocess the test images and texts
test_image_path = list_image_path[:50]
test_texts = list_txt[:50]

# preprocess the image
test_images = [Image.open(img_path).convert("RGB") for img_path in test_image_path]
test_images_preprocessed = torch.cat([preprocess(images=img, return_tensors="pt")["pixel_values"] for img in test_images]).to(device)

# preprocess the text
test_texts_preprocessed = clip.tokenize(test_texts).to(device)

# %%
# without Tuning
with torch.no_grad():
    outputs = model(pixel_values=test_images_preprocessed, input_ids=test_texts_preprocessed)
    logits_per_image, logits_per_text = outputs.logits_per_image, outputs.logits_per_text

# with Tuning
with torch.no_grad():
    outputstuning = modeltuning(pixel_values=test_images_preprocessed, input_ids=test_texts_preprocessed)
    logits_per_imagetuning, logits_per_texttuning = outputstuning.logits_per_image, outputstuning.logits_per_text


def check_success(logits):
    success_count = 0
    for m, image_list in enumerate(logits.tolist()):
        max_similarity = max(image_list)
        for n, similarity in enumerate(image_list):
            #print(f"Similarity between image {m + 1} and description {n + 1}: {similarity}\n")
            if m == n and similarity == max_similarity:
                success_count += 1
    return success_count

print("Before Tuning: \n")
success_count_of_image =check_success(logits_per_image)
success_count_of_text = check_success(logits_per_text)
print(f"\nCount of successful recognitions: {success_count_of_image + success_count_of_text}\n")


print("\nAfter Tuning: \n")
success_count_of_image = check_success(logits_per_imagetuning)
success_count_of_text = check_success(logits_per_texttuning)
print(f"\nCount of successful recognitions: {success_count_of_image + success_count_of_text}\n")
# Out:
# Before Tuning:
#
#
# Count of successful recognitions: 2
#
#
# After Tuning:
#
#
# Count of successful recognitions: 1
